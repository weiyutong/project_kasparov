# %%
import chess.pgn
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
import sklearn as skl
import statsmodels.api as sm

# %% [markdown]
# Load and parse a `.pgn` file with all the games from FIDE World Cup 2019 using `chess.pgn`. [Documentation](https://python-chess.readthedocs.io/en/v0.28.3/pgn.html)

# %%
path = "./Data/wcup19.pgn"
tournament = open(path)

#first_game = chess.pgn.read_game(tournament)
#second_game = chess.pgn.read_game(tournament)

# %%
#print(first_game)

# %%
#print(second_game)

# %%
#outputs `Headers` object

# %%
#first_game.headers['ECO']

# %%
# first_game_Elos = [first_game.headers['WhiteElo'],first_game.headers['BlackElo']]
# first_game_Elos

# %%
# first_game.headers['Event']

# %% [markdown]
# Load all of the games into a DataFrame with relevant fields

# %%
params = ['WhiteElo', 'BlackElo', 'ECO', 'Opening', 'Result']

# %%
# def parse_pgn(file, params):
#     games_df = pd.DataFrame(columns = params)
#     for game in file:
#         cur_game = chess.pgn.read_game(file)
#         cur_row = [cur_game.headers[info] for info in params]
#         games_df.append(cur_row)
#     return games_df

# %%
#parse_pgn(tournament, params)

# %%
list_of_games = []
for game in tournament:
    cur_game = chess.pgn.read_game(tournament) # remember to reload each time
    cur_row = [cur_game.headers[info] for info in params]
    list_of_games.append(cur_row)

# %%
list_of_games
# Out:
# [['1954', '2811', 'B26', 'Sicilian', '0-1'],
#  ['2780', '2250', 'B52', 'Sicilian', '1-0'],
#  ['2284', '2774', 'A29', 'English', '0-1'],
#  ['2767', '2387', 'A20', 'English opening', '1-0'],
#  ['2407', '2776', 'B90', 'Sicilian', '0-1'],
#  ['2758', '2431', 'A36', 'English', '1/2-1/2'],
#  ['2428', '2767', 'B15', 'Caro-Kann', '0-1'],
#  ['2763', '2504', 'B40', 'Sicilian', '1-0'],
#  ['2503', '2759', 'D43', 'QGD semi-Slav', '0-1'],
#  ['2758', '2533', 'E62', "King's Indian", '1-0'],
#  ['2540', '2746', 'B12', 'Caro-Kann', '1/2-1/2'],
#  ['2763', '2544', 'D25', 'QGA, 4.e3', '1-0'],
#  ['2550', '2760', 'E00', 'Catalan opening', '0-1'],
#  ['2745', '2540', 'E04', 'Catalan', '1/2-1/2'],
#  ['2558', '2741', 'D11', 'QGD Slav', '1/2-1/2'],
#  ['2739', '2558', 'E60', "King's Indian", '0-1'],
#  ['2552', '2746', 'C53', 'Giuoco Piano', '0-1'],
#  ['2730', '2587', 'B69', 'Sicilian', '1-0'],
#  ['2581', '2729', 'A33', 'English', '1/2-1/2'],
#  ['2732', '2550', 'E01', 'Catalan', '1/2-1/2'],
#  ['2560', '2721', 'B90', 'Sicilian', '1/2-1/2'],
#  ['2708', '2577', 'C65', 'Ruy Lopez', '1/2-1/2'],
#  ['2577', '2724', 'E12', "Queen's Indian", '1/2-1/2'],
#  ['2721', '2576', 'A07', 'Reti', '1/2-1/2'],
#  ['2599', '2726', 'B91', 'Sicilian', '1/2-1/2'],
#  ['2705', '2593', 'D10', 'QGD Slav defence', '1/2-1/2'],
#  ['2608', '2716', 'C78', 'Ruy Lopez', '1/2-1/2'],
#  ['2718', '2586', 'E17', "Queen's Indian", '1/2-1/2'],
#  ['2600', '2718', 'C67', 'Ruy Lopez', '1/2-1/2'],
#  ['2681', '2596', 'B90', 'Sicilian', '1-0'],
#  ['2596', '2707', 'D26', 'QGA', '0-1'],
#  ['2702', '2599', 'A06', 'Reti opening', '1-0'],
#  ['2576', '2699', 'D78', 'Neo-Gruenfeld, 6.O-O c6', '0-1'],
#  ['2699', '2642', 'C50', 'Giuoco Piano', '1/2-1/2'],
#  ['2602', '2688', 'D85', 'Gruenfeld', '0-1'],
#  ['2691', '2606', 'C42', 'Petrov', '1/2-1/2'],
#  ['2609', '2694', 'E20', 'Nimzo-Indian', '1/2-1/2'],
#  ['2686', '2602', 'E04', 'Catalan', '1/2-1/2'],
#  ['2610', '2676', 'B32', 'Sicilian', '1-0'],
#  ['2684', '2621', 'A29', 'English', '1-0'],
#  ['2617', '2693', 'C92', 'Ruy Lopez', '1/2-1/2'],
#  ['2682', '2615', 'A04', 'Reti opening', '1/2-1/2'],
#  ['2609', '2679', 'D36', 'QGD', '1/2-1/2'],
#  ['2674', '2611', 'A20', 'English opening', '1-0'],
#  ['2620', '2643', 'C19', 'French', '1-0'],
#  ['2675', '2624', 'B19', 'Caro-Kann', '0-1'],
#  ['2624', '2658', 'A21', 'English opening', '0-1'],
#  ['2664', '2658', 'E46', 'Nimzo-Indian', '1-0'],
#  ['2638', '2671', 'C45', 'Scotch', '1/2-1/2'],
#  ['2666', '2630', 'D73', 'Neo-Gruenfeld, 5.Nf3', '1/2-1/2'],
#  ['2629', '2656', 'C42', "Petrov's defence", '1/2-1/2'],
#  ['2654', '2630', 'D38', 'QGD', '1-0'],
#  ['2626', '2639', 'A21', 'English, Kramnik-Shirov counterattack', '0-1'],
#  ['2670', '2636', 'D37', 'QGD', '1-0'],
#  ['2633', '2662', 'B90', 'Sicilian', '1/2-1/2'],
#  ['2667', '2640', 'C67', 'Ruy Lopez', '1/2-1/2'],
#  ['2632', '2660', 'E04', 'Catalan', '1/2-1/2'],
#  ['2657', '2643', 'C24', "Bishop's opening", '1-0'],
#  ['2644', '2664', 'C50', 'Giuoco Piano', '0-1'],
#  ['2651', '2657', 'D37', 'QGD', '1/2-1/2'],
#  ['2639', '2655', 'C60', 'Ruy Lopez', '0-1'],
#  ['2674', '2643', 'C02', 'French', '1-0'],
#  ['2635', '2654', 'D87', 'Gruenfeld', '1/2-1/2'],
#  ['2654', '2654', 'C78', 'Ruy Lopez', '1/2-1/2'],
#  ['2811', '1954', 'A18', 'English', '1-0'],
#  ['2250', '2780', 'B30', 'Sicilian defence', '0-1'],
#  ['2774', '2284', 'C84', 'Ruy Lopez', '1-0'],
#  ['2387', '2767', 'A14', 'English', '0-1'],
#  ['2776', '2407', 'B66', 'Sicilian', '1-0'],
#  ['2431', '2758', 'E24', 'Nimzo-Indian', '0-1'],
#  ['2767', '2428', 'A15', 'English opening', '1-0'],
#  ['2504', '2763', 'B53', 'Sicilian, Chekhover variation', '0-1'],
#  ['2759', '2503', 'D85', 'Gruenfeld', '1-0'],
#  ['2533', '2758', 'C50', 'Giuoco Piano', '1/2-1/2'],
#  ['2746', '2540', 'A05', 'Reti', '1-0'],
#  ['2544', '2763', 'D12', 'QGD Slav', '1-0'],
#  ['2760', '2550', 'B07', 'Pirc defence', '1/2-1/2'],
#  ['2540', '2745', 'B15', 'Caro-Kann', '1/2-1/2'],
#  ['2741', '2558', 'D02', "Queen's pawn game", '1/2-1/2'],
#  ['2558', '2739', 'B94', 'Sicilian', '1-0'],
#  ['2746', '2552', 'E15', "Queen's Indian", '1-0'],
#  ['2587', '2730', 'C42', 'Petrov', '1/2-1/2'],
#  ['2729', '2581', 'B30', 'Sicilian', '1-0'],
#  ['2550', '2732', 'E21', 'Nimzo-Indian', '0-1'],
#  ['2721', '2560', 'C78', 'Ruy Lopez', '1-0'],
#  ['2577', '2708', 'E46', 'Nimzo-Indian', '1/2-1/2'],
#  ['2724', '2577', 'B12', 'Caro-Kann', '0-1'],
#  ['2576', '2721', 'D10', 'QGD Slav defence', '1/2-1/2'],
#  ['2726', '2599', 'E06', 'Catalan', '1/2-1/2'],
#  ['2593', '2705', 'C69', 'Ruy Lopez', '1/2-1/2'],
#  ['2716', '2608', 'B91', 'Sicilian', '1/2-1/2'],
#  ['2586', '2718', 'E35', 'Nimzo-Indian', '1/2-1/2'],
#  ['2718', '2600', 'E04', 'Catalan', '1-0'],
#  ['2596', '2681', 'A30', 'English', '0-1'],
#  ['2707', '2596', 'C01', 'French', '1-0'],
#  ['2599', '2702', 'D37', 'QGD', '1/2-1/2'],
#  ['2699', '2576', 'E10', "Queen's pawn game", '1/2-1/2'],
#  ['2642', '2699', 'D85', 'Gruenfeld', '1/2-1/2'],
#  ['2688', '2602', 'C72', 'Ruy Lopez', '1/2-1/2'],
#  ['2606', '2691', 'A30', 'English', '1-0'],
#  ['2694', '2609', 'C50', 'Giuoco Piano', '1/2-1/2'],
#  ['2602', '2686', 'C46', 'Four knights', '1/2-1/2'],
#  ['2676', '2610', 'A13', 'English opening', '0-1'],
#  ['2621', '2684', 'D11', 'QGD Slav', '1/2-1/2'],
#  ['2693', '2617', 'E97', "King's Indian", '1-0'],
#  ['2615', '2682', 'C67', 'Ruy Lopez', '1/2-1/2'],
#  ['2679', '2609', 'D80', 'Gruenfeld', '1/2-1/2'],
#  ['2611', '2674', 'C65', 'Ruy Lopez', '1-0'],
#  ['2643', '2620', 'E04', 'Catalan', '0-1'],
#  ['2624', '2675', 'E68', "King's Indian", '1/2-1/2'],
#  ['2658', '2624', 'B22', 'Sicilian', '0-1'],
#  ['2658', '2664', 'A13', 'English', '1-0'],
#  ['2671', '2638', 'C53', 'Giuoco Piano', '1-0'],
#  ['2630', '2666', 'E62', "King's Indian", '1-0'],
#  ['2656', '2629', 'C45', 'Scotch', '1/2-1/2'],
#  ['2630', '2654', 'A06', 'Reti opening', '1/2-1/2'],
#  ['2639', '2626', 'E46', 'Nimzo-Indian', '1/2-1/2'],
#  ['2636', '2670', 'E60', "King's Indian", '1/2-1/2'],
#  ['2662', '2633', 'E15', "Queen's Indian", '1/2-1/2'],
#  ['2640', '2667', 'E94', "King's Indian", '1/2-1/2'],
#  ['2660', '2632', 'B30', 'Sicilian', '1/2-1/2'],
#  ['2643', '2657', 'A22', 'English', '1/2-1/2'],
#  ['2664', '2644', 'B06', 'Robatsch defence', '1-0'],
#  ['2657', '2651', 'E35', 'Nimzo-Indian', '1/2-1/2'],
#  ['2655', '2639', 'A43', 'Old Benoni defence', '1/2-1/2'],
#  ['2643', '2674', 'C45', 'Scotch', '1-0'],
#  ['2654', '2635', 'A09', 'Reti', '0-1'],
#  ['2654', '2654', 'E00', 'Catalan opening', '0-1'],
#  ['2544', '2763', 'D82', 'Gruenfeld', '1/2-1/2'],
#  ['2540', '2745', 'C67', 'Ruy Lopez', '0-1'],
#  ['2741', '2558', 'A37', 'English', '1-0'],
#  ['2708', '2577', 'D31', 'QGD', '1-0'],
#  ['2721', '2576', 'A22', 'English', '1/2-1/2'],
#  ['2599', '2726', 'B11', 'Caro-Kann', '1/2-1/2'],
#  ['2705', '2593', 'D10', 'QGD Slav defence', '1/2-1/2'],
#  ['2608', '2716', 'C78', 'Ruy Lopez', '1/2-1/2'],
#  ['2586',
#   '2718',
#   'A45',
#   'Trompovsky attack (Ruth, Opovcensky opening)',
#   '1/2-1/2'],
#  ['2642', '2699', 'E94', "King's Indian", '1-0'],
#  ['2694', '2609', 'C80', 'Ruy Lopez', '1/2-1/2'],
#  ['2686', '2602', 'E04', 'Catalan', '1/2-1/2'],
#  ['2682', '2615', 'A13', 'English', '1-0'],
#  ['2679', '2609', 'A48', "King's Indian", '0-1'],
#  ['2611', '2674', 'C65', 'Ruy Lopez', '1/2-1/2'],
#  ['2624', '2658', 'D20', 'QGA', '0-1'],
#  ['2664', '2658', 'B92', 'Sicilian', '1/2-1/2'],
#  ['2629', '2656', 'C11', 'French', '1/2-1/2'],
#  ['2662', '2633', 'E15', "Queen's Indian", '1-0'],
#  ['2640', '2667', 'D43', 'QGD semi-Slav', '1-0'],
#  ['2632', '2660', 'E08', 'Catalan', '1-0'],
#  ['2651', '2657', 'D38', 'QGD', '0-1'],
#  ['2674', '2643', 'A18', 'English', '1-0'],
#  ['2763', '2544', 'C42', 'Petrov', '1/2-1/2'],
#  ['2745', '2540', 'A33', 'English', '1-0'],
#  ['2558', '2741', 'E00', 'Catalan opening', '1/2-1/2'],
#  ['2577', '2708', 'D20', 'QGA', '1/2-1/2'],
#  ['2576', '2721', 'C42', 'Petrov', '1/2-1/2'],
#  ['2726', '2599', 'D35', 'QGD', '1/2-1/2'],
#  ['2593', '2705', 'C44', 'Scotch gambit', '1/2-1/2'],
#  ['2716', '2608', 'B91', 'Sicilian', '1-0'],
#  ['2718', '2586', 'E17', "Queen's Indian", '1-0'],
#  ['2699', '2642', 'A07', 'Reti', '1/2-1/2'],
#  ['2609', '2694', 'D35', 'QGD', '1/2-1/2'],
#  ['2602', '2686', 'C43', 'Petrov', '1/2-1/2'],
#  ['2615', '2682', 'C65', 'Ruy Lopez', '1/2-1/2'],
#  ['2609', '2679', 'A41', 'Robatsch defence', '0-1'],
#  ['2674', '2611', 'A13', 'English', '1-0'],
#  ['2658', '2624', 'A46', "Queen's pawn game", '1-0'],
#  ['2658', '2664', 'D46', 'QGD semi-Slav', '1/2-1/2'],
#  ['2656', '2629', 'D02', "Queen's pawn game", '1-0'],
#  ['2633', '2662', 'C88', 'Ruy Lopez', '1/2-1/2'],
#  ['2667', '2640', 'C65', 'Ruy Lopez', '1/2-1/2'],
#  ['2660', '2632', 'B31', 'Sicilian', '1-0'],
#  ['2657', '2651', 'A50', "Queen's Indian accelerated", '1/2-1/2'],
#  ['2643', '2674', 'B40', 'Sicilian', '1/2-1/2'],
#  ['2544', '2763', 'D82', 'Gruenfeld', '1/2-1/2'],
#  ['2721', '2576', 'D23', 'QGA', '0-1'],
#  ['2599', '2726', 'B23', 'Sicilian', '1/2-1/2'],
#  ['2593', '2705', 'C44', 'Scotch gambit', '1-0'],
#  ['2609', '2694', 'D35', 'QGD', '1/2-1/2'],
#  ['2686', '2602', 'E04', 'Catalan', '1-0'],
#  ['2679', '2609', 'E60', "King's Indian", '1-0'],
#  ['2658', '2664', 'A11', 'English', '0-1'],
#  ['2660', '2632', 'B30', 'Sicilian', '0-1'],
#  ['2763', '2544', 'C42', 'Petrov', '1-0'],
#  ['2576', '2721', 'B23', 'Sicilian', '1/2-1/2'],
#  ['2726', '2599', 'A13', 'English opening', '1-0'],
#  ['2705', '2593', 'D10', 'QGD Slav defence', '1/2-1/2'],
#  ['2694', '2609', 'C77', 'Ruy Lopez', '1/2-1/2'],
#  ['2602', '2686', 'C24', "Bishop's opening", '0-1'],
#  ['2609', '2679', 'D36', 'QGD', '0-1'],
#  ['2664', '2658', 'E91', "King's Indian", '1-0'],
#  ['2632', '2660', 'A81', 'Dutch defence', '0-1'],
#  ['2694', '2609', 'C77', 'Ruy Lopez', '1/2-1/2'],
#  ['2632', '2660', 'A81', 'Dutch defence', '1/2-1/2'],
#  ['2609', '2694', 'C50', 'Giuoco Piano', '1-0'],
#  ['2660', '2632', 'B31', 'Sicilian', '0-1'],
#  ['2811', '2654', 'D12', 'QGD Slav', '1/2-1/2'],
#  ['2635',
#   '2780',
#   'A45',
#   'Trompovsky attack (Ruth, Opovcensky opening)',
#   '1/2-1/2'],
#  ['2774', '2674', 'B40', 'Sicilian', '1-0'],
#  ['2655', '2767', 'D02', "Queen's bishop game", '1/2-1/2'],
#  ['2776', '2657', 'C65', 'Ruy Lopez', '1/2-1/2'],
#  ['2664', '2758', 'C65', 'Ruy Lopez', '0-1'],
#  ['2767', '2657', 'D30', 'QGD', '1-0'],
#  ['2632', '2763', 'E06', 'Catalan', '1/2-1/2'],
#  ['2759', '2640', 'E04', 'Catalan', '1/2-1/2'],
#  ['2662', '2758', 'D37', 'QGD', '1/2-1/2'],
#  ['2746', '2670', 'A04', 'Reti opening', '1-0'],
#  ['2639', '2763', 'E46', 'Nimzo-Indian', '1/2-1/2'],
#  ['2760', '2654', 'A07', 'Reti', '1-0'],
#  ['2656', '2745', 'D37', 'QGD', '1-0'],
#  ['2741', '2630', 'B90', 'Sicilian', '1/2-1/2'],
#  ['2671', '2558', 'C11', 'French', '1/2-1/2'],
#  ['2746', '2664', 'D35', 'QGD', '1-0'],
#  ['2658', '2730', 'A46', "Queen's pawn game", '0-1'],
#  ['2729', '2624', 'B10', 'Caro-Kann defence', '1/2-1/2'],
#  ['2620', '2732', 'C84', 'Ruy Lopez', '1/2-1/2'],
#  ['2721', '2674', 'C50', 'Giuoco Pianissimo', '0-1'],
#  ['2679', '2708', 'D00', "Queen's pawn, Mason variation", '1/2-1/2'],
#  ['2577', '2682', 'E94', "King's Indian", '1/2-1/2'],
#  ['2693', '2576', 'D11', 'QGD Slav', '1/2-1/2'],
#  ['2726', '2684', 'E60', "King's Indian", '1/2-1/2'],
#  ['2610', '2593', 'C95', 'Ruy Lopez', '1-0'],
#  ['2716', '2686', 'D47', 'QGD semi-Slav', '1/2-1/2'],
#  ['2609', '2718', 'C50', 'Giuoco Pianissimo', '0-1'],
#  ['2718', '2606', 'D31', 'QGD', '1/2-1/2'],
#  ['2688', '2681', 'C67', 'Ruy Lopez', '1/2-1/2'],
#  ['2707', '2642', 'C65', 'Ruy Lopez', '1/2-1/2'],
#  ['2699', '2702', 'A29', 'English', '1/2-1/2'],
#  ['2654', '2811', 'C47', 'Four knights', '1/2-1/2'],
#  ['2780', '2635', 'A21', 'English, Kramnik-Shirov counterattack', '1/2-1/2'],
#  ['2674', '2774', 'B23', 'Sicilian', '0-1'],
#  ['2767', '2655', 'D31', 'QGD', '1-0'],
#  ['2657', '2776', 'D90', 'Gruenfeld', '0-1'],
#  ['2758', '2664', 'C01', 'French', '1/2-1/2'],
#  ['2657', '2767', 'C53', 'Giuoco Piano', '1/2-1/2'],
#  ['2763', '2632', 'B31', 'Sicilian', '1/2-1/2'],
#  ['2640', '2759', 'D38', 'QGD', '1/2-1/2'],
#  ['2758', '2662', 'D02', "Queen's pawn game", '1/2-1/2'],
#  ['2670', '2746', 'D15', 'QGD Slav', '1/2-1/2'],
#  ['2763', '2639', 'B53', 'Sicilian, Chekhover variation', '1/2-1/2'],
#  ['2654', '2760', 'C53', 'Giuoco Piano', '0-1'],
#  ['2745', '2656', 'C42', 'Petrov', '1/2-1/2'],
#  ['2630', '2741', 'D37', 'QGD', '0-1'],
#  ['2558', '2671', 'C47', 'Four knights', '1/2-1/2'],
#  ['2664', '2746', 'A18', 'English', '1/2-1/2'],
#  ['2730', '2658', 'A21', 'English opening', '1-0'],
#  ['2624', '2729', 'D85', 'Gruenfeld', '1/2-1/2'],
#  ['2732', '2620', 'C84', 'Ruy Lopez', '1/2-1/2'],
#  ['2674', '2721', 'A20', 'English opening', '0-1'],
#  ['2708', '2679', 'B23', 'Sicilian', '1-0'],
#  ['2682', '2577', 'B11', 'Caro-Kann', '1/2-1/2'],
#  ['2576', '2693', 'E21', 'Nimzo-Indian', '1-0'],
#  ['2684', '2726', 'D12', 'QGD Slav', '0-1'],
#  ['2593', '2610', 'C52', 'Evans gambit', '1-0'],
#  ['2686', '2716', 'A28', 'English', '1/2-1/2'],
#  ['2718', '2609', 'D07', 'QGD', '1/2-1/2'],
#  ['2606', '2718', 'A35', 'English', '0-1'],
#  ['2681', '2688', 'C78', 'Ruy Lopez', '1/2-1/2'],
#  ['2642', '2707', 'D90', 'Gruenfeld', '1/2-1/2'],
#  ['2702', '2699', 'B31', 'Sicilian', '1-0'],
#  ['2811', '2654', 'A20', 'English opening', '1-0'],
#  ['2635', '2780', 'C45', 'Scotch', '1/2-1/2'],
#  ['2763', '2632', 'B30', 'Sicilian', '1-0'],
#  ['2759', '2640', 'E46', 'Nimzo-Indian', '1/2-1/2'],
#  ['2662', '2758', 'E06', 'Catalan', '1/2-1/2'],
#  ['2639', '2763', 'D38', 'QGD', '0-1'],
#  ['2671', '2558', 'C02', 'French', '1-0'],
#  ['2624', '2729', 'D11', 'QGD Slav', '0-1'],
#  ['2732', '2620', 'E51', 'Nimzo-Indian', '1-0'],
#  ['2721', '2674', 'D00', "Queen's pawn game", '1/2-1/2'],
#  ['2682', '2577', 'B12', 'Caro-Kann', '0-1'],
#  ['2593', '2610', 'C53', 'Giuoco Piano', '1-0'],
#  ['2716', '2686', 'D43', 'QGD semi-Slav', '1-0'],
#  ['2681', '2688', 'C78', 'Ruy Lopez', '1-0'],
#  ['2707', '2642', 'D37', 'QGD', '1-0'],
#  ['2654', '2811', 'A15', 'English opening', '1/2-1/2'],
#  ['2780', '2635', 'A20', 'English opening', '1/2-1/2'],
#  ['2632', '2763', 'A45', "Queen's pawn game", '0-1'],
#  ['2640', '2759', 'D59', 'QGD', '0-1'],
#  ['2758', '2662', 'D37', 'QGD', '1-0'],
#  ['2763', '2639', 'B93', 'Sicilian', '1/2-1/2'],
#  ['2558', '2671', 'D37', 'QGD', '1/2-1/2'],
#  ['2729', '2624', 'B18', 'Caro-Kann', '1-0'],
#  ['2620', '2732', 'C91', 'Ruy Lopez', '0-1'],
#  ['2674', '2721', 'A10', 'English', '0-1'],
#  ['2577', '2682', 'E94', "King's Indian", '0-1'],
#  ['2610', '2593', 'A06', 'Reti opening', '1/2-1/2'],
#  ['2686', '2716', 'A20', 'English opening', '1/2-1/2'],
#  ['2688', '2681', 'C67', 'Ruy Lopez', '0-1'],
#  ['2642', '2707', 'D20', 'QGA', '0-1'],
#  ['2780', '2635', 'A20', 'English opening', '1/2-1/2'],
#  ['2577', '2682', 'E92', "King's Indian", '1-0'],
#  ['2635', '2780', 'C45', 'Scotch', '1/2-1/2'],
#  ['2682', '2577', 'B11', 'Caro-Kann', '1-0'],
#  ['2635', '2780', 'C26', 'Vienna', '0-1'],
#  ['2682', '2577', 'B11', 'Caro-Kann', '0-1'],
#  ['2780', '2635', 'E11', 'Bogo-Indian defence', '0-1'],
#  ['2577', '2682', 'A49', "King's Indian", '1-0'],
#  ['2635', '2780', 'A28', 'English', '0-1'],
#  ['2702', '2811', 'E20', 'Nimzo-Indian', '1/2-1/2'],
#  ['2780', '2707', 'D26', 'QGA', '1/2-1/2'],
#  ['2681', '2774', 'A15', 'English opening', '1/2-1/2'],
#  ['2767', '2718', 'D38', 'QGD', '1-0'],
#  ['2718', '2776', 'E60', "King's Indian, 3.Nf3", '1/2-1/2'],
#  ['2758', '2716', 'A09', 'Reti', '1/2-1/2'],
#  ['2593', '2767', 'C41', 'Philidor', '0-1'],
#  ['2763', '2726', 'C65', 'Ruy Lopez', '1/2-1/2'],
#  ['2576', '2759', 'D38', 'QGD', '0-1'],
#  ['2758', '2577', 'B11', 'Caro-Kann', '1-0'],
#  ['2708', '2746', 'C76', 'Ruy Lopez', '1/2-1/2'],
#  ['2763', '2721', 'D85', 'Gruenfeld', '1/2-1/2'],
#  ['2732', '2760', 'C65', 'Ruy Lopez', '1-0'],
#  ['2656', '2729', 'C91', 'Ruy Lopez', '1/2-1/2'],
#  ['2730', '2741', 'C50', 'Giuoco Piano', '1-0'],
#  ['2671', '2746', 'C50', 'Giuoco Piano', '1-0'],
#  ['2811', '2702', 'E06', 'Catalan', '1/2-1/2'],
#  ['2707', '2780', 'C67', 'Ruy Lopez', '1/2-1/2'],
#  ['2774', '2681', 'C67', 'Ruy Lopez', '1/2-1/2'],
#  ['2718', '2767', 'A29', 'English', '1/2-1/2'],
#  ['2776', '2718', 'C67', 'Ruy Lopez', '1/2-1/2'],
#  ['2716', '2758', 'C50', 'Giuoco Pianissimo', '0-1'],
#  ['2767', '2593', 'A04', 'Reti v Dutch', '1/2-1/2'],
#  ['2726', '2763', 'C67', 'Ruy Lopez', '1/2-1/2'],
#  ['2759', '2576', 'E10', "Queen's pawn game", '1-0'],
#  ['2577', '2758', 'E21', 'Nimzo-Indian', '1/2-1/2'],
#  ['2746', '2708', 'A33', 'English', '1/2-1/2'],
#  ['2721', '2763', 'C99', 'Ruy Lopez', '1/2-1/2'],
#  ['2760', '2732', 'C53', 'Giuoco Piano', '1/2-1/2'],
#  ['2729', '2656', 'C17', 'French', '1/2-1/2'],
#  ['2741', '2730', 'D30', 'QGD Slav', '1/2-1/2'],
#  ['2746', '2671', 'C84', 'Ruy Lopez', '0-1'],
#  ['2811', '2702', 'D37', 'QGD', '1-0'],
#  ['2707', '2780', 'A28', 'English', '1/2-1/2'],
#  ['2681', '2774', 'A34', 'English', '1-0'],
#  ['2718', '2776', 'E60', "King's Indian, 3.Nf3", '1/2-1/2'],
#  ['2726', '2763', 'A28', 'English', '1-0'],
#  ['2746', '2708', 'D00', "Levitsky attack (Queen's bishop attack)", '1/2-1/2'],
#  ['2763', '2721', 'B93', 'Sicilian', '1/2-1/2'],
#  ['2656', '2729', 'A15', 'English opening', '1/2-1/2'],
#  ['2702', '2811', 'A06', 'Reti opening', '0-1'],
#  ['2780', '2707', 'A30', 'English', '1/2-1/2'],
#  ['2774', '2681', 'C53', 'Giuoco Piano', '1-0'],
#  ['2776', '2718', 'C48', 'Four knights', '1/2-1/2'],
#  ['2763', '2726', 'C42', 'Petrov', '1-0'],
#  ['2708', '2746', 'A22', 'English', '1/2-1/2'],
#  ['2721', '2763', 'D15', 'QGD Slav', '0-1'],
#  ['2729', '2656', 'B12', 'Caro-Kann', '1-0'],
#  ['2707', '2780', 'A28', 'English', '1/2-1/2'],
#  ['2681', '2774', 'A34', 'English', '1/2-1/2'],
#  ['2776', '2718', 'C49', 'Four knights', '1-0'],
#  ['2726', '2763', 'A28', 'English', '1-0'],
#  ['2708', '2746', 'D20', 'QGA', '1-0'],
#  ['2780', '2707', 'A04', 'Reti opening', '0-1'],
#  ['2774', '2681', 'C53', 'Giuoco Piano', '1/2-1/2'],
#  ['2718', '2776', 'D78', 'Neo-Gruenfeld, 6.O-O c6', '1-0'],
#  ['2763', '2726', 'C65', 'Ruy Lopez', '1-0'],
#  ['2746', '2708', 'B31', 'Sicilian', '1/2-1/2'],
#  ['2774', '2681', 'C53', 'Giuoco Piano', '1-0'],
#  ['2776', '2718', 'C48', 'Four knights', '1-0'],
#  ['2763', '2726', 'C65', 'Ruy Lopez', '1-0'],
#  ['2681', '2774', 'A30', 'English', '1/2-1/2'],
#  ['2718', '2776', 'A48', "King's Indian", '0-1'],
#  ['2726', '2763', 'A08', 'Reti', '1/2-1/2'],
#  ['2811', '2671', 'E01', 'Catalan', '1/2-1/2'],
#  ['2730', '2707', 'A35', 'English', '1-0'],
#  ['2774', '2729', 'C99', 'Ruy Lopez', '1-0'],
#  ['2732', '2767', 'C43', 'Petrov', '1-0'],
#  ['2776', '2763', 'B33', 'Sicilian', '1/2-1/2'],
#  ['2708', '2758', 'C88', 'Ruy Lopez', '1/2-1/2'],
#  ['2767', '2758', 'C67', 'Ruy Lopez', '1/2-1/2'],
#  ['2759', '2763', 'A14', 'English', '1-0'],
#  ['2671', '2811', 'C50', 'Giuoco Pianissimo', '1/2-1/2'],
#  ['2707', '2730', 'C24', "Bishop's opening", '1-0'],
#  ['2729', '2774', 'B90', 'Sicilian', '1/2-1/2'],
#  ['2767', '2732', 'C88', 'Ruy Lopez', '1/2-1/2'],
#  ['2763', '2776', 'D85', 'Gruenfeld', '1-0'],
#  ['2758', '2708', 'B31', 'Sicilian', '1/2-1/2'],
#  ['2758', '2767', 'D85', 'Gruenfeld', '1/2-1/2'],
#  ['2763', '2759', 'C53', 'Giuoco Piano', '1-0'],
#  ['2811', '2671', 'A20', 'English opening', '1-0'],
#  ['2707', '2730', 'C43', 'Petrov', '1-0'],
#  ['2758', '2708', 'B31', 'Sicilian', '1/2-1/2'],
#  ['2758', '2767', 'C50', 'Giuoco Pianissimo', '1/2-1/2'],
#  ['2763', '2759', 'C53', 'Giuoco Piano', '1/2-1/2'],
#  ['2671', '2811', 'C53', 'Giuoco Piano', '0-1'],
#  ['2730', '2707', 'A00', "Anderssen's opening", '1-0'],
#  ['2708', '2758', 'E06', 'Catalan', '1/2-1/2'],
#  ['2767', '2758', 'D35', 'QGD', '1/2-1/2'],
#  ['2759', '2763', 'A14', 'English', '1-0'],
#  ['2730', '2707', 'B12', 'Caro-Kann', '1-0'],
#  ['2708', '2758', 'A28', 'English', '0-1'],
#  ['2758', '2767', 'A34', 'English', '1/2-1/2'],
#  ['2707', '2730', 'C42', 'Petrov', '1-0'],
#  ['2758', '2708', 'A40', 'Modern defence', '1/2-1/2'],
#  ['2767', '2758', 'D35', 'QGD', '0-1'],
#  ['2730', '2707', 'B12', 'Caro-Kann', '1/2-1/2'],
#  ['2707', '2730', 'B03', "Alekhine's defence", '1-0'],
#  ['2759', '2811', 'E04', 'Catalan', '1/2-1/2'],
#  ['2707', '2758', 'E06', 'Catalan', '1/2-1/2'],
#  ['2758', '2774', 'D91', 'Gruenfeld', '1/2-1/2'],
#  ['2732', '2763', 'B91', 'Sicilian', '1/2-1/2'],
#  ['2811', '2759', 'A20', 'English opening', '1-0'],
#  ['2758', '2707', 'D85', 'Gruenfeld', '1-0'],
#  ['2774', '2758', 'C50', 'Giuoco Pianissimo', '1/2-1/2'],
#  ['2763', '2732', 'E32', 'Nimzo-Indian', '1/2-1/2'],
#  ['2758', '2774', 'A04', 'Reti opening', '1/2-1/2'],
#  ['2763', '2732', 'E32', 'Nimzo-Indian', '1/2-1/2'],
#  ['2774', '2758', 'C50', 'Giuoco Pianissimo', '1-0'],
#  ['2732', '2763', 'B56', 'Sicilian', '1/2-1/2'],
#  ['2763', '2732', 'C88', 'Ruy Lopez', '1-0'],
#  ['2732', '2763', 'C43', 'Petrov', '1-0'],
#  ['2763', '2732', 'C01', 'French', '1/2-1/2'],
#  ['2732', '2763', 'B40', 'Sicilian defence', '1/2-1/2'],
#  ['2763', '2732', 'C00', 'French', '1-0'],
#  ['2811', '2763', 'A20', 'English opening', '1/2-1/2'],
#  ['2774', '2758', 'B31', 'Sicilian', '1/2-1/2'],
#  ['2763', '2811', 'E36', 'Nimzo-Indian', '1/2-1/2'],
#  ['2758', '2774', 'A34', 'English', '1-0'],
#  ['2763', '2811', 'E21', 'Nimzo-Indian', '1/2-1/2'],
#  ['2811', '2763', 'A21', 'English, Kramnik-Shirov counterattack', '1-0'],
#  ['2758', '2811', 'C89', 'Ruy Lopez', '1/2-1/2'],
#  ['2763', '2774', 'D97', 'Gruenfeld', '1/2-1/2'],
#  ['2811', '2758', 'A19', 'English', '1-0'],
#  ['2774', '2763', 'C42', 'Petrov', '1/2-1/2'],
#  ['2758', '2811', 'C89', 'Ruy Lopez', '1-0'],
#  ['2763', '2774', 'D86', 'Gruenfeld', '1/2-1/2']]

# %%
games_df = pd.DataFrame(list_of_games, columns = params)

# %%
games_df
# Out:
#     WhiteElo BlackElo  ECO          Opening   Result
# 0       1954     2811  B26         Sicilian      0-1
# 1       2780     2250  B52         Sicilian      1-0
# 2       2284     2774  A29          English      0-1
# 3       2767     2387  A20  English opening      1-0
# 4       2407     2776  B90         Sicilian      0-1
# ..       ...      ...  ...              ...      ...
# 421     2763     2774  D97        Gruenfeld  1/2-1/2
# 422     2811     2758  A19          English      1-0
# 423     2774     2763  C42           Petrov  1/2-1/2
# 424     2758     2811  C89        Ruy Lopez      1-0
# 425     2763     2774  D86        Gruenfeld  1/2-1/2
#
# [426 rows x 5 columns]

# %% [markdown]
# Doing some EDA

# %%
games_df.describe()
# Out:
#        WhiteElo BlackElo  ECO    Opening   Result
# count       426      426  426        426      426
# unique      100      100  153         53        3
# top        2763     2763  C50  Ruy Lopez  1/2-1/2
# freq         26       24   14         52      220

# %%
games_df.dtypes
# Out:
# WhiteElo    object
# BlackElo    object
# ECO         object
# Opening     object
# Result      object
# dtype: object

# %%
games_df['WhiteElo'] = games_df['WhiteElo'].astype(int)

# %%
games_df['BlackElo'] = games_df['BlackElo'].astype(int)

# %%
games_df
# Out:
#      WhiteElo  BlackElo  ECO          Opening   Result
# 0        2811      2811  B26         Sicilian      0-1
# 1        2250      2250  B52         Sicilian      1-0
# 2        2774      2774  A29          English      0-1
# 3        2387      2387  A20  English opening      1-0
# 4        2776      2776  B90         Sicilian      0-1
# ..        ...       ...  ...              ...      ...
# 421      2774      2774  D97        Gruenfeld  1/2-1/2
# 422      2758      2758  A19          English      1-0
# 423      2763      2763  C42           Petrov  1/2-1/2
# 424      2811      2811  C89        Ruy Lopez      1-0
# 425      2774      2774  D86        Gruenfeld  1/2-1/2
#
# [426 rows x 5 columns]

# %%
games_df.describe()
# Out:
#           WhiteElo     BlackElo
# count   426.000000   426.000000
# mean   2681.950704  2681.950704
# std      85.354347    85.354347
# min    1954.000000  1954.000000
# 25%    2635.000000  2635.000000
# 50%    2688.000000  2688.000000
# 75%    2746.000000  2746.000000
# max    2811.000000  2811.000000

# %%
games_df['ECO'].nunique()
# Out:
# 153

# %%
games_df['Opening'].nunique()
# Out:
# 53

# %%
games_df['Result'].unique()
# Out:
# array(['0-1', '1-0', '1/2-1/2'], dtype=object)

# %%
games_df_ECOs = games_df.groupby('ECO')
games_df_ECOs.size().sort_values(ascending = False)
# Out:
# ECO
# C50    14
# C65    12
# C53    12
# C67    11
# C42    10
#        ..
# C69     1
# C72     1
# C76     1
# C80     1
# A00     1
# Length: 153, dtype: int64

# %% [markdown]
# Most popular ECO opening is C50 'Giuoco Piano'

# %%
games_df_Openings = games_df.groupby('Opening')
games_df_Openings.size().sort_values(ascending = False)
# Out:
# Opening
# Ruy Lopez                                       52
# Sicilian                                        41
# English                                         41
# QGD                                             30
# Giuoco Piano                                    19
# English opening                                 18
# Nimzo-Indian                                    18
# Catalan                                         18
# Gruenfeld                                       17
# King's Indian                                   17
# Caro-Kann                                       15
# Petrov                                          13
# QGD Slav                                        10
# French                                          10
# Queen's pawn game                                9
# Reti opening                                     8
# Reti                                             7
# Giuoco Pianissimo                                7
# QGA                                              7
# Four knights                                     6
# Queen's Indian                                   6
# QGD semi-Slav                                    5
# Scotch                                           5
# QGD Slav defence                                 4
# Bishop's opening                                 3
# English, Kramnik-Shirov counterattack            3
# Catalan opening                                  3
# Sicilian, Chekhover variation                    2
# Sicilian defence                                 2
# Scotch gambit                                    2
# King's Indian, 3.Nf3                             2
# Trompovsky attack (Ruth, Opovcensky opening)     2
# Neo-Gruenfeld, 6.O-O c6                          2
# Robatsch defence                                 2
# Dutch defence                                    2
# Evans gambit                                     1
# Bogo-Indian defence                              1
# Caro-Kann defence                                1
# Anderssen's opening                              1
# Vienna                                           1
# Levitsky attack (Queen's bishop attack)          1
# Modern defence                                   1
# Neo-Gruenfeld, 5.Nf3                             1
# Old Benoni defence                               1
# Petrov's defence                                 1
# Philidor                                         1
# Pirc defence                                     1
# QGA, 4.e3                                        1
# Queen's Indian accelerated                       1
# Queen's bishop game                              1
# Queen's pawn, Mason variation                    1
# Reti v Dutch                                     1
# Alekhine's defence                               1
# dtype: int64

# %% [markdown]
# Ruy Lopez is most popular named opening

# %%
games_df.groupby(['Result','Opening']).size().sort_values(ascending = False)
# Out:
# Result   Opening
# 1/2-1/2  Ruy Lopez                                35
#          Sicilian                                 21
# 1-0      English                                  17
# 1/2-1/2  English                                  16
#          Catalan                                  14
#                                                   ..
# 0-1      Vienna                                    1
#          Sicilian, Chekhover variation             1
#          Sicilian defence                          1
# 1/2-1/2  English, Kramnik-Shirov counterattack     1
# 0-1      Bishop's opening                          1
# Length: 104, dtype: int64
